# %%
$PSVersionTable.PSVersion
Echo "----------------------------------------------------------------"
python --version
# Out:
# <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>7.5.1</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Major</td><td><div class="dni-plaintext"><pre>7</pre></div></td></tr><tr><td>Minor</td><td><div class="dni-plaintext"><pre>5</pre></div></td></tr><tr><td>Patch</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>PreReleaseLabel</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr><tr><td>BuildLabel</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
# ...
